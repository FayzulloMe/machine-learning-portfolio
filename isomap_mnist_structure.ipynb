# %%
from sklearn.datasets import fetch_openml

import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.manifold import Isomap

# %%
mnist = fetch_openml("mnist_784", version=1, as_frame=False)  # downloads once, then caches
X = mnist.data.astype(np.float32)
y = mnist.target.astype(np.int64)

# %%
fig, ax = plt.subplots(6, 8, subplot_kw = dict(xticks=[], yticks=[]))

for i, axi in enumerate(ax.flat):
    axi.imshow(mnist.data[1250*i].reshape(28, 28), cmap='gray_r')

# %%
model = Isomap(n_components=2)
proj = model.fit_transform(X)

plt.scatter(proj[:, 0], proj[:, 1], c=y, cmap='tab10')
plt.colorbar(ticks=range(10))
plt.clim(-0.5, 9.5)

# %% [markdown]
# Это поможет нам понять какие действия мы можем принимать с данными(напр. шумы и избыточные зависимости в данных)
